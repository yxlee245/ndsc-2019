# %% [markdown]
# # Preparing the Data to Train Bounding Box

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# Auto update from code base

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import os
import shutil
import zipfile
import glob
from tqdm import tqdm
import skimage
from PIL import Image
from PIL.ImageDraw import Draw
from torchvision import transforms

from src.data import pil_loader
from src.image_preprocessing import draw_dots, draw_rectangle

# %% [markdown]
# ## Sample data to be used for training and validating bounding box model

# %%
df_beauty_train = pd.read_csv('data/raw/beauty_data_info_train_competition.csv')
df_beauty_val = pd.read_csv('data/raw/beauty_data_info_val_competition.csv')

df_fashion_train = pd.read_csv('data/raw/fashion_data_info_train_competition.csv')
df_fashion_val = pd.read_csv('data/raw/fashion_data_info_val_competition.csv')

df_mobile_train = pd.read_csv('data/raw/mobile_data_info_train_competition.csv')
df_mobile_val = pd.read_csv('data/raw/mobile_data_info_val_competition.csv')

# %%
df_beauty_sample = df_beauty_train.sample(n=500, random_state=2019).reset_index(drop=True)

df_fashion_sample = df_fashion_train.sample(n=500, random_state=2019).reset_index(drop=True)

df_mobile_sample = df_mobile_train.sample(n=500, random_state=2019).reset_index(drop=True)

# %%
# df_beauty_bb_train = pd.DataFrame({'image_path': df_beauty_train_sample['image_path']}).reset_index(drop=True)
# df_beauty_bb_val = pd.DataFrame({'image_path': df_beauty_val_sample['image_path']}).reset_index(drop=True)

# df_fashion_bb_train = pd.DataFrame({'image_path': df_fashion_train_sample['image_path']}).reset_index(drop=True)
# df_fashion_bb_val = pd.DataFrame({'image_path': df_fashion_val_sample['image_path']}).reset_index(drop=True)

# df_mobile_bb_train = pd.DataFrame({'image_path': df_mobile_train_sample['image_path']}).reset_index(drop=True)
# df_mobile_bb_val = pd.DataFrame({'image_path': df_mobile_val_sample['image_path']}).reset_index(drop=True)

# df_beauty_bb_train.to_csv('data/derived/beauty_image_path_train.csv', index=False)
# df_beauty_bb_val.to_csv('data/derived/beauty_image_path_val.csv', index=False)

# df_fashion_bb_train.to_csv('data/derived/fashion_image_path_train.csv', index=False)
# df_fashion_bb_val.to_csv('data/derived/fashion_image_path_val.csv', index=False)

# df_mobile_bb_train.to_csv('data/derived/mobile_image_path_train.csv', index=False)
# df_mobile_bb_val.to_csv('data/derived/mobile_image_path_val.csv', index=False)

# %% [markdown]
# ## Output sampled images

# %% [markdown]
# Beauty

# %%
with tqdm(total=len(df_beauty_sample)) as pbar:
    for img_path_short in df_beauty_sample['image_path']:
        if img_path_short[-4:] != '.jpg': img_path_short += '.jpg'
        img_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/raw', img_path_short)
        dest_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/derived/bb_images/', img_path_short)
        shutil.copy(img_path_full,dest_path_full)
        pbar.update()
# Out:
# 100%|██████████| 500/500 [00:16<00:00, 29.89it/s]

# %% [markdown]
# Fashion

# %%
with tqdm(total=len(df_fashion_sample)) as pbar:
    for img_path_short in df_fashion_sample['image_path']:
        if img_path_short[-4:] != '.jpg': img_path_short += '.jpg'
        img_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/raw', img_path_short)
        dest_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/derived/bb_images/', img_path_short)
        shutil.copy(img_path_full,dest_path_full)
        pbar.update()
# Out:
# 100%|██████████| 500/500 [00:25<00:00, 15.51it/s]

# %% [markdown]
# Mobile

# %%
with tqdm(total=len(df_mobile_sample)) as pbar:
    for img_path_short in df_mobile_sample['image_path']:
        if img_path_short[-4:] != '.jpg': img_path_short += '.jpg'
        img_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/raw', img_path_short)
        dest_path_full = os.path.join('/home/yxlee245/ndsc-2019/data/derived/bb_images/', img_path_short)
        shutil.copy(img_path_full,dest_path_full)
        pbar.update()
# Out:
# 100%|██████████| 500/500 [00:19<00:00, 26.18it/s]

# %%
glob.glob('data/derived/bb_images/beauty_image/*.jpg')
# Out:
# ['data/derived/bb_images/beauty_image/be190be3146d9cd88501be5c44ce67b9.jpg',
#  'data/derived/bb_images/beauty_image/bbac977e8eb187479c5e88b68e340bb4.jpg',
#  'data/derived/bb_images/beauty_image/aef8adf75eb343c217a5881016f860d4.jpg',
#  'data/derived/bb_images/beauty_image/1d922cbcd8ac15ba535e10d302b0f11e.jpg',
#  'data/derived/bb_images/beauty_image/3af85f5a138884604a7f6246d4f5e185.jpg',
#  'data/derived/bb_images/beauty_image/0456864c4b19ee9ed5a37dbc9e833d1c.jpg',
#  'data/derived/bb_images/beauty_image/113a5d19b28705729673e8325b6b2342.jpg',
#  'data/derived/bb_images/beauty_image/95983185e4c84532092ab0ba55ea8c74.jpg',
#  'data/derived/bb_images/beauty_image/374c2f8735f1ea7d5c522a4cc4745b01.jpg',
#  'data/derived/bb_images/beauty_image/d54f7c51a9ee2639678cb43ceb6ef7ea.jpg',
#  'data/derived/bb_images/beauty_image/5782138ebcc1d0e6d026a5d7da4daf2f.jpg',
#  'data/derived/bb_images/beauty_image/e6d32e05b610da9409fb870ce75a317e.jpg',
#  'data/derived/bb_images/beauty_image/954dc53c3b07c49c1235e4a20cada6ed.jpg',
#  'data/derived/bb_images/beauty_image/ba50b6089a61b6028b6a79ca812dd80c.jpg',
#  'data/derived/bb_images/beauty_image/36b6d79bde9bac28d1c33df49e77aab6.jpg',
#  'data/derived/bb_images/beauty_image/bfe34235b7d010b2cac62077e7e86d32.jpg',
#  'data/derived/bb_images/beauty_image/406d416f105227888ab257f767b39986.jpg',
#  'data/derived/bb_images/beauty_image/83350bf9e3197723f9906121d04463c8.jpg',
#  'data/derived/bb_images/beauty_image/53ac0ff940a68ce2f6e2b1119f5046ca.jpg',
#  'data/derived/bb_images/beauty_image/8e29577321072e4094c24f4027aed331.jpg',
#  'data/derived/bb_images/beauty_image/684a77abccbe5c7ba1efc3c095e75765.jpg',
#  'data/derived/bb_images/beauty_image/16f630f789c9d2e4fad7a04ad3d2a41d.jpg',
#  'data/derived/bb_images/beauty_image/22e1279899df631eb41ec3e0d4f8d1fb.jpg',
#  'data/derived/bb_images/beauty_image/61b4e726ca289b49bfa5b50a11e6e8ff.jpg',
#  'data/derived/bb_images/beauty_image/4341ab364b918b3e59396a8cebf12112.jpg',
#  'data/derived/bb_images/beauty_image/18b5196613fd51efbaa9a243a1a2a1f3.jpg',
#  'data/derived/bb_images/beauty_image/7641df5398734b3149398165f589a8c3.jpg',
#  'data/derived/bb_images/beauty_image/08e1a90c7db72ce6261ee10a753da209.jpg',
#  'data/derived/bb_images/beauty_image/22d4c6f0bc9eac0a8052fd25d3f02ebb.jpg',
#  'data/derived/bb_images/beauty_image/c2f74c5a722f76b1bc123b9899c7178e.jpg',
#  'data/derived/bb_images/beauty_image/e79564f7e6d90f0ea6e862cd3a39fd1b.jpg',
#  'data/derived/bb_images/beauty_image/cd129854acfb88278b4f9ca7bb4ea9c9.jpg',
#  'data/derived/bb_images/beauty_image/6728cda0d386d429f153ee6a256cfb3c.jpg',
#  'data/derived/bb_images/beauty_image/d7c4e0dc828ccde974e44c33c219dea5.jpg',
#  'data/derived/bb_images/beauty_image/2fad89257a8a0604b9607267643d028c.jpg',
#  'data/derived/bb_images/beauty_image/7594d8817aeef9ff03cce16994ade032.jpg',
#  'data/derived/bb_images/beauty_image/3f5d12b4e474800b93d094e6962880c9.jpg',
#  'data/derived/bb_images/beauty_image/4d0226b6847ab4f488e1592b20a3ed2c.jpg',
#  'data/derived/bb_images/beauty_image/aaabe86513ebdd1a51dd1a36f40123b0.jpg',
#  'data/derived/bb_images/beauty_image/8d8e1d62b07c6708d4f94a99fe2c3ee1.jpg',
#  'data/derived/bb_images/beauty_image/fb3bdfedb241aac15db2e9c856a31544.jpg',
#  'data/derived/bb_images/beauty_image/542479a3c95c78447f7b56a26eadc7b8.jpg',
#  'data/derived/bb_images/beauty_image/58ed253bcbb1b1cde543de86c0c1a535.jpg',
#  'data/derived/bb_images/beauty_image/32fcf03524e6b5b7926265ae4b70e8ff.jpg',
#  'data/derived/bb_images/beauty_image/115b5625f57627a7e96b93a3360b0b2a.jpg',
#  'data/derived/bb_images/beauty_image/8f542d249e9c7f1de4afed3a14de42a0.jpg',
#  'data/derived/bb_images/beauty_image/691b50e37c19806a1b498980aafae811.jpg',
#  'data/derived/bb_images/beauty_image/de78a5d6a80d7345225d987122bc6991.jpg',
#  'data/derived/bb_images/beauty_image/8c1178fd78a4ea79d402f5e74404e342.jpg',
#  'data/derived/bb_images/beauty_image/97751619ba4a75754c0cad9b1520648e.jpg',
#  'data/derived/bb_images/beauty_image/af7d2507a7f9f485d35cb6861b4b22cd.jpg',
#  'data/derived/bb_images/beauty_image/6a785bb617d8902b03438b4174f1663c.jpg',
#  'data/derived/bb_images/beauty_image/642112fa94f44d39f33ccdc471a8838a.jpg',
#  'data/derived/bb_images/beauty_image/d9940c372efb883d969304a78e50bf70.jpg',
#  'data/derived/bb_images/beauty_image/6e4358da3b670202531c65c510436387.jpg',
#  'data/derived/bb_images/beauty_image/fdb8e54d14f5e21a5eb846a1161de53f.jpg',
#  'data/derived/bb_images/beauty_image/eece929d5bc709714152b3af88c509db.jpg',
#  'data/derived/bb_images/beauty_image/95fdee101e37bd82f3b2d5b1b75d0779.jpg',
#  'data/derived/bb_images/beauty_image/3a422bab0dd3fb7888b93e080ddda3c6.jpg',
#  'data/derived/bb_images/beauty_image/92528888414db659dcd6e16683cc0258.jpg',
#  'data/derived/bb_images/beauty_image/a30781e60bf145680c6b35dfe57264f7.jpg',
#  'data/derived/bb_images/beauty_image/c5ccbaa9961138781be8a0ba4b2ea0c4.jpg',
#  'data/derived/bb_images/beauty_image/3c221c664878f97e32998ff3b26cc5d3.jpg',
#  'data/derived/bb_images/beauty_image/436e6f923d0c69aae9d53051542b39a0.jpg',
#  'data/derived/bb_images/beauty_image/a7bff0610827d31d582e5eb901ae0c24.jpg',
#  'data/derived/bb_images/beauty_image/5b168108c568d078f5b240414f2b4c07.jpg',
#  'data/derived/bb_images/beauty_image/0341a41588f3dc87de32231a110684f2.jpg',
#  'data/derived/bb_images/beauty_image/8236783813e3bf79dff4605e8569c0a2.jpg',
#  'data/derived/bb_images/beauty_image/8eec6dbcde6c5b7f2541bb51b9eaefa1.jpg',
#  'data/derived/bb_images/beauty_image/5d1803ad379f481c99182065ba24840d.jpg',
#  'data/derived/bb_images/beauty_image/a7dd52ae289ad2ff35bfa896323652e1.jpg',
#  'data/derived/bb_images/beauty_image/8ffe2cc91da712e333699c1b7217713d.jpg',
#  'data/derived/bb_images/beauty_image/755cc4f1c8b08e850e4d186216876ce0.jpg',
#  'data/derived/bb_images/beauty_image/f124d6562cd49b70d2a14f6df2c3d289.jpg',
#  'data/derived/bb_images/beauty_image/68a5be7e2889522a760276406d0fb494.jpg',
#  'data/derived/bb_images/beauty_image/639204c1e3a18556b9acfe2deab249ac.jpg',
#  'data/derived/bb_images/beauty_image/5874f5736c6bb3da37ef597eb89b5b7d.jpg',
#  'data/derived/bb_images/beauty_image/42f10218ffbff5b9f8190b3aa43c0256.jpg',
#  'data/derived/bb_images/beauty_image/cb53a4f3634eb827fb46ef3fd22923ca.jpg',
#  'data/derived/bb_images/beauty_image/d559bdd0699a028b604f29efe0f285a6.jpg',
#  'data/derived/bb_images/beauty_image/a4afae83db2ee982e94b7e9870b85037.jpg',
#  'data/derived/bb_images/beauty_image/900fbc938fc050f602f6b3e31a0391b4.jpg',
#  'data/derived/bb_images/beauty_image/6886b8cb269cf27e79d95d92d398c924.jpg',
#  'data/derived/bb_images/beauty_image/e23c17247fd5d24740829ca32997e7d2.jpg',
#  'data/derived/bb_images/beauty_image/470c57200755cf8a266f6b787da3e11e.jpg',
#  'data/derived/bb_images/beauty_image/ba7ecafad7f23097f9ea199de4243a9b.jpg',
#  'data/derived/bb_images/beauty_image/eef830b5ae3d15649167d095252dffc4.jpg',
#  'data/derived/bb_images/beauty_image/f1781d3e54624d92eab209c5ecd25baf.jpg',
#  'data/derived/bb_images/beauty_image/60e0fa96a51ad5c7a8429037120c6184.jpg',
#  'data/derived/bb_images/beauty_image/c479562242200a0346f8fa33804d6efc.jpg',
#  'data/derived/bb_images/beauty_image/a2b13987eff32e3de87e8e248c14b887.jpg',
#  'data/derived/bb_images/beauty_image/58c5cd90d3af8b8e5268848330cf64e3.jpg',
#  'data/derived/bb_images/beauty_image/80853b6cae2c593f5665b0456104ef94.jpg',
#  'data/derived/bb_images/beauty_image/d6891ea4438e5903ad2fc40e069b1a44.jpg',
#  'data/derived/bb_images/beauty_image/26450e3c3b9280a545b3d0e91dc2ba7d.jpg',
#  'data/derived/bb_images/beauty_image/b3f2ccae7800ad147b93edd0aa42ff1d.jpg',
#  'data/derived/bb_images/beauty_image/8f989dbbb6ca988019de7be22f16d9b6.jpg',
#  'data/derived/bb_images/beauty_image/7e0ac27a8c1a01f0ac406b52dd93e443.jpg',
#  'data/derived/bb_images/beauty_image/29e83b5a2713a8fbe5bb7d80cecef8ca.jpg',
#  'data/derived/bb_images/beauty_image/e0eb331bd858764c36ec27b2c91de52c.jpg',
#  'data/derived/bb_images/beauty_image/b639f680223b9677103d33ff32e76a83.jpg',
#  'data/derived/bb_images/beauty_image/44b4f5bf592bfab9b545d68dfd143794.jpg',
#  'data/derived/bb_images/beauty_image/f3dd32592db6b61dfbebe45ea2a62b1d.jpg',
#  'data/derived/bb_images/beauty_image/31409a5466d9cdabda24548f4049c4da.jpg',
#  'data/derived/bb_images/beauty_image/f39ddd722eead8aebae536728a7ef340.jpg',
#  'data/derived/bb_images/beauty_image/93a7677f830a8fbb21679551dec79284.jpg',
#  'data/derived/bb_images/beauty_image/8d2b2911fa3ea5f977d532e4aa08ebdc.jpg',
#  'data/derived/bb_images/beauty_image/abb455b6ad9896dc1c14577ff7e7d52e.jpg',
#  'data/derived/bb_images/beauty_image/9acb9bf5417812162e90d0f9eea6215a.jpg',
#  'data/derived/bb_images/beauty_image/6bf0b0b05dc78fd39fd43aaa3910af13.jpg',
#  'data/derived/bb_images/beauty_image/b7df1ccebaa2de3c743a99ce684f1471.jpg',
#  'data/derived/bb_images/beauty_image/1fb549975f33ca48d0ba5d2683a41cde.jpg',
#  'data/derived/bb_images/beauty_image/969914daedf9ca4c8473d5d743956ee8.jpg',
#  'data/derived/bb_images/beauty_image/0975577369256a56911047e2a0297554.jpg',
#  'data/derived/bb_images/beauty_image/406d14879e8c9eee6b5c4c2c5442ad76.jpg',
#  'data/derived/bb_images/beauty_image/d349ca602c8054c10b9ed2e61307ac68.jpg',
#  'data/derived/bb_images/beauty_image/72f059c2190fbcb7114cefcc465e1a39.jpg',
#  'data/derived/bb_images/beauty_image/8e3610d91e3798766ee3dc57e1550534.jpg',
#  'data/derived/bb_images/beauty_image/9dc5c5ca8a8f343f3578df470d8f1c92.jpg',
#  'data/derived/bb_images/beauty_image/5944fcc7f201ff8fe48e029349e78d99.jpg',
#  'data/derived/bb_images/beauty_image/16a4fbf35340571d556295d842e1171b.jpg',
#  'data/derived/bb_images/beauty_image/b76b556913b588514cf9a60722778397.jpg',
#  'data/derived/bb_images/beauty_image/3907402fbf60a8cf89de8e2dd7094366.jpg',
#  'data/derived/bb_images/beauty_image/d02876c24f74723116c82c0cd4804a93.jpg',
#  'data/derived/bb_images/beauty_image/e6afe16d7524df7ae972500933fd2c0b.jpg',
#  'data/derived/bb_images/beauty_image/d7739cc8ba496a8627d1f3ccd7960885.jpg',
#  'data/derived/bb_images/beauty_image/aa0fbe5f1a9af27539d7daa913fc62cc.jpg',
#  'data/derived/bb_images/beauty_image/4171c7a1881dedc8de9a0659e35a454d.jpg',
#  'data/derived/bb_images/beauty_image/b8232c6801b959d54a5a233ca3ffe94a.jpg',
#  'data/derived/bb_images/beauty_image/f6d28385cb8dc0b0ed785166883305fd.jpg',
#  'data/derived/bb_images/beauty_image/8d91253bd537d8954f6a2b4cc30a86fc.jpg',
#  'data/derived/bb_images/beauty_image/8dc26d71bffa94dfd8324e0c9fdd4f55.jpg',
#  'data/derived/bb_images/beauty_image/5c50e9688d28fe3cfd9d85112954b698.jpg',
#  'data/derived/bb_images/beauty_image/b12ed34714cd9070d690608774ed463f.jpg',
#  'data/derived/bb_images/beauty_image/eca709cfbd38e2a4b0f124be85cc2fd0.jpg',
#  'data/derived/bb_images/beauty_image/3a0044fbd417b42cb94894cda4d721ac.jpg',
#  'data/derived/bb_images/beauty_image/079b6929e897b84ca9452b1f00156859.jpg',
#  'data/derived/bb_images/beauty_image/7738da241a9c2de0ced1fc81ec2fe93a.jpg',
#  'data/derived/bb_images/beauty_image/5d7864a076044b0306b9eae5f50285d6.jpg',
#  'data/derived/bb_images/beauty_image/b430f1c493685206931e8e6f85b1611c.jpg',
#  'data/derived/bb_images/beauty_image/9615151770ab6bd2ff788e99c875f691.jpg',
#  'data/derived/bb_images/beauty_image/2db252aacf6d8d8ed7cb29ee80a5dad2.jpg',
#  'data/derived/bb_images/beauty_image/50310b5296bf8864c253ca2bad8943ea.jpg',
#  'data/derived/bb_images/beauty_image/3ba931b6816e55b9d688b295eb415200.jpg',
#  'data/derived/bb_images/beauty_image/f4dc93d70de71ba50759eabba12308eb.jpg',
#  'data/derived/bb_images/beauty_image/83f7ef62269c403dc489391444f026a5.jpg',
#  'data/derived/bb_images/beauty_image/7a4e183656d5603483d60c2ddafcaa23.jpg',
#  'data/derived/bb_images/beauty_image/9fc7eb66053e34342119d79484c666fa.jpg',
#  'data/derived/bb_images/beauty_image/2b2bfe6005615c3b6bb5fe0beeaf7e13.jpg',
#  'data/derived/bb_images/beauty_image/83c34f8c04f1a23f7b509db499222dfb.jpg',
#  'data/derived/bb_images/beauty_image/ab4b52a15f271c1a421a60f4e5cb0035.jpg',
#  'data/derived/bb_images/beauty_image/692166a74dca65af5061f1ae6c7cfa5a.jpg',
#  'data/derived/bb_images/beauty_image/f13b793497d1e341847dbdbd9a27c58c.jpg',
#  'data/derived/bb_images/beauty_image/bdba2a6df37384bef73c7778c2608fee.jpg',
#  'data/derived/bb_images/beauty_image/28b960cda3cfd980be5e0b5185458dde.jpg',
#  'data/derived/bb_images/beauty_image/fe182f07b93ab37ce586ae3c4c56933e.jpg',
#  'data/derived/bb_images/beauty_image/48f7fc6c2083eaf4018ef01dda40e50c.jpg',
#  'data/derived/bb_images/beauty_image/abd46149f77d3917c5006957d25f5baf.jpg',
#  'data/derived/bb_images/beauty_image/2ae68e54e482680f80ef32d0096dd017.jpg',
#  'data/derived/bb_images/beauty_image/d1276c0cfd1fc55b32fff000e5292dfb.jpg',
#  'data/derived/bb_images/beauty_image/c6170c2fe709653ac8a9f21da5184a5e.jpg',
#  'data/derived/bb_images/beauty_image/4c8407d50229be071a547d5e32288054.jpg',
#  'data/derived/bb_images/beauty_image/7b9679baa11e60fe6f2f9992faf656a6.jpg',
#  'data/derived/bb_images/beauty_image/99d295c8a4b46bc5118f3d1f6d703db1.jpg',
#  'data/derived/bb_images/beauty_image/457cf83a503029282c94a3412728de4d.jpg',
#  'data/derived/bb_images/beauty_image/e256dbb775f0053502c719af13121c95.jpg',
#  'data/derived/bb_images/beauty_image/be21232a2dfe2f05f628e64e3423c445.jpg',
#  'data/derived/bb_images/beauty_image/d6050db5fbafe0c5ab02a1dd573c55fa.jpg',
#  'data/derived/bb_images/beauty_image/4dff96c58cb0ee84ef148fac9e1fc105.jpg',
#  'data/derived/bb_images/beauty_image/ef021ecf9e3a963f1e1f08178742b314.jpg',
#  'data/derived/bb_images/beauty_image/b21512dfeab48ea27e77cafdc197bcfd.jpg',
#  'data/derived/bb_images/beauty_image/cd050bb70c69e0c77b6e9c7300425f87.jpg',
#  'data/derived/bb_images/beauty_image/2294ab8099dea314bd374ee90978b24e.jpg',
#  'data/derived/bb_images/beauty_image/b4f4bf2db39c7f5cdbe6b6ceb73e3e50.jpg',
#  'data/derived/bb_images/beauty_image/5cfa6bbbbad51bff6631473a71f7e16d.jpg',
#  'data/derived/bb_images/beauty_image/d5cde4564248de4afd100f1d4636e855.jpg',
#  'data/derived/bb_images/beauty_image/5bebea56241b2b6034b31a311ea748a8.jpg',
#  'data/derived/bb_images/beauty_image/7079698b8abe0e3665fc8f8f83ac5e74.jpg',
#  'data/derived/bb_images/beauty_image/7fee00878e66a2325f693da0e311f2cf.jpg',
#  'data/derived/bb_images/beauty_image/c54187bd97ce3775eb4fc401e63e7df2.jpg',
#  'data/derived/bb_images/beauty_image/1536d699a734f831fd4319346bdbb57f.jpg',
#  'data/derived/bb_images/beauty_image/563111e3ecaec1548a3a8b10358db859.jpg',
#  'data/derived/bb_images/beauty_image/dbbed5111c41829bdfd695d045cdc677.jpg',
#  'data/derived/bb_images/beauty_image/5486a551715bcbbaf378400b6fd29f8e.jpg',
#  'data/derived/bb_images/beauty_image/affdf435839b976afa9b52994c630f6d.jpg',
#  'data/derived/bb_images/beauty_image/c6bba5cfefff4aec18aa4425ee5f2175.jpg',
#  'data/derived/bb_images/beauty_image/b204e041c9c0f29c765a2307d0ed337b.jpg',
#  'data/derived/bb_images/beauty_image/892ee989112ea4b89d0c2c0c6bc52c1a.jpg',
#  'data/derived/bb_images/beauty_image/23efd5e0e981a89f170c36956c572caa.jpg',
#  'data/derived/bb_images/beauty_image/761c5eb35c88d8f81e6f98aed0f775ec.jpg',
#  'data/derived/bb_images/beauty_image/164d2d47be9dc25b9fb35409c0add2ed.jpg',
#  'data/derived/bb_images/beauty_image/90b458167f8bfc774217fec1fce39b0d.jpg',
#  'data/derived/bb_images/beauty_image/74dbfa6ec3e2c72557f8fe2a73b7dc67.jpg',
#  'data/derived/bb_images/beauty_image/dbae51c6ef3d7bf6ea9353ccb37e8fa1.jpg',
#  'data/derived/bb_images/beauty_image/f1fe7fd6bfcb3596a42699d4c1fe5c96.jpg',
#  'data/derived/bb_images/beauty_image/e48022154b33cc3d1c576434bd38be18.jpg',
#  'data/derived/bb_images/beauty_image/b9e06a8eb14cbf5b003dafd82c87b424.jpg',
#  'data/derived/bb_images/beauty_image/923b2b8dd0cd51017862665da0444912.jpg',
#  'data/derived/bb_images/beauty_image/ca860db4f8b33a819c7d5a5fd326f80e.jpg',
#  'data/derived/bb_images/beauty_image/f32477a2dbf33281772ea9faa9fd897e.jpg',
#  'data/derived/bb_images/beauty_image/51dcaf38a8f774e69edb8020c8ee1ebb.jpg',
#  'data/derived/bb_images/beauty_image/f210d7b5e57d5cae0c038f5db6428b66.jpg',
#  'data/derived/bb_images/beauty_image/56de827aa7a54af599a9e335226972ab.jpg',
#  'data/derived/bb_images/beauty_image/ba41998dcba18fc3f51619675355df8a.jpg',
#  'data/derived/bb_images/beauty_image/92c18ef97aa9481d2be907cf16c46696.jpg',
#  'data/derived/bb_images/beauty_image/2e37fe264d94b2512b61b4063e9c859e.jpg',
#  'data/derived/bb_images/beauty_image/b084ea68377179b87a9039d12437df79.jpg',
#  'data/derived/bb_images/beauty_image/0f854f76988c16d367ceb39067b6a551.jpg',
#  'data/derived/bb_images/beauty_image/d61ec13083919b96c94eefe5a0b706f1.jpg',
#  'data/derived/bb_images/beauty_image/046cc7ce489ff497c8e90bfb297b5cf2.jpg',
#  'data/derived/bb_images/beauty_image/2c723b5723e32197512c25088bc09a96.jpg',
#  'data/derived/bb_images/beauty_image/b1df6a1fcbc8447df554c0b0c75313ee.jpg',
#  'data/derived/bb_images/beauty_image/4d1e95854fd04aa243dccfd6825a4f91.jpg',
#  'data/derived/bb_images/beauty_image/c42a0658630637b0c04f078788fdb717.jpg',
#  'data/derived/bb_images/beauty_image/bf95c73914befec3befb42357b7ec00f.jpg',
#  'data/derived/bb_images/beauty_image/e86f34ea57f23bb21dc9aff1d082b4f0.jpg',
#  'data/derived/bb_images/beauty_image/93052cc5aa503c94cac8f17a8dabd5b7.jpg',
#  'data/derived/bb_images/beauty_image/8fb0b54fea141419ab38a91a201832e3.jpg',
#  'data/derived/bb_images/beauty_image/b178548141fe90169bfe01df6803c9db.jpg',
#  'data/derived/bb_images/beauty_image/06e751cb6802f45db7422af242ce399c.jpg',
#  'data/derived/bb_images/beauty_image/e41653c3117e8d18b496acf3777ef289.jpg',
#  'data/derived/bb_images/beauty_image/de228681acc950f3e48b5b399b2bdc75.jpg',
#  'data/derived/bb_images/beauty_image/17ef4355b48a3f80495fcbe6d872304e.jpg',
#  'data/derived/bb_images/beauty_image/694e0ec85bf2a33cfe13210c6e4e0559.jpg',
#  'data/derived/bb_images/beauty_image/5678d30d558c50bedeab560077f80a6b.jpg',
#  'data/derived/bb_images/beauty_image/cbed39ae702e70fa1b62960d12194a91.jpg',
#  'data/derived/bb_images/beauty_image/6b822790314fc64e1ff847d49240633c.jpg',
#  'data/derived/bb_images/beauty_image/38a3b27a3d951ccae80406c465d8350f.jpg',
#  'data/derived/bb_images/beauty_image/aab58a42075a7196919bff566f88736d.jpg',
#  'data/derived/bb_images/beauty_image/5aed7af619669e8aa44e7c256b70e176.jpg',
#  'data/derived/bb_images/beauty_image/e5dce333b8830d88c42db23e4797b181.jpg',
#  'data/derived/bb_images/beauty_image/dd469e3a6a7d3f7aa348898f53fab7aa.jpg',
#  'data/derived/bb_images/beauty_image/6a9061234c17f82989e3ce1ba6aeb243.jpg',
#  'data/derived/bb_images/beauty_image/4594f5382942f10b78526b673aa7e429.jpg',
#  'data/derived/bb_images/beauty_image/b0b9c216373bc3ba903a6d4f856bd1f1.jpg',
#  'data/derived/bb_images/beauty_image/2594c3612b16572993b16cfd3130a969.jpg',
#  'data/derived/bb_images/beauty_image/72d06c727a02635e2426c83c39e49713.jpg',
#  'data/derived/bb_images/beauty_image/10c77426fc068c392228076134f24dd1.jpg',
#  'data/derived/bb_images/beauty_image/de1f443ab5dd3242d9f57d41fa092195.jpg',
#  'data/derived/bb_images/beauty_image/bf3d026bfe8bcb81d16e31b45a42fa3b.jpg',
#  'data/derived/bb_images/beauty_image/9cdb03f2f3d962dbf2a305d1c45def21.jpg',
#  'data/derived/bb_images/beauty_image/4fe9920c06e0d5f16d619e6f745149aa.jpg',
#  'data/derived/bb_images/beauty_image/2c147fd4a40b67ff25c8f1fdea427a08.jpg',
#  'data/derived/bb_images/beauty_image/c9dba3f472f12a3d7d8aa45c3dd53a80.jpg',
#  'data/derived/bb_images/beauty_image/e114d68b03c2e0b488333eefc861dd8b.jpg',
#  'data/derived/bb_images/beauty_image/3c698da59cb01efb14d361d2c4e2f7cd.jpg',
#  'data/derived/bb_images/beauty_image/0b6b7936bbb0e7bbc70ca93c77b44506.jpg',
#  'data/derived/bb_images/beauty_image/50a4591374985ccc365e8fd68e3977af.jpg',
#  'data/derived/bb_images/beauty_image/1258316589df1fa8d095cc2c9d26743a.jpg',
#  'data/derived/bb_images/beauty_image/9729ff4116b66d3a152024aa8b82ef50.jpg',
#  'data/derived/bb_images/beauty_image/a91e7bd55eb546a8e5ae41f12b5eadbc.jpg',
#  'data/derived/bb_images/beauty_image/012f0e489c0760ef9bd6006f440615da.jpg',
#  'data/derived/bb_images/beauty_image/d5288f6b6c356be7130bda4047058c54.jpg',
#  'data/derived/bb_images/beauty_image/e4e281fd1c94eeda7176d1a1e349f30f.jpg',
#  'data/derived/bb_images/beauty_image/0537df606e97b49de872a6d1bed55acb.jpg',
#  'data/derived/bb_images/beauty_image/14ba0b85fc6b9edb3525a77ce50e87c7.jpg',
#  'data/derived/bb_images/beauty_image/24f873f284046e1428c612a82cb3f854.jpg',
#  'data/derived/bb_images/beauty_image/a4d36591362ac650014a4fa41685746d.jpg',
#  'data/derived/bb_images/beauty_image/c7750433f8556e756cf36bbc332544a2.jpg',
#  'data/derived/bb_images/beauty_image/1b7b2fe472eb1f74af67789ecdff597c.jpg',
#  'data/derived/bb_images/beauty_image/a24b931a761f3556c060e000ac16b2d9.jpg',
#  'data/derived/bb_images/beauty_image/d81948e36a3d4610baca9ac79244b0db.jpg',
#  'data/derived/bb_images/beauty_image/58bc4c04f925aa5ceb54ed896f6b2aef.jpg',
#  'data/derived/bb_images/beauty_image/5b72d559a0a9af041b2c98844134eb04.jpg',
#  'data/derived/bb_images/beauty_image/c665a89f031ab0c7c6683fc7d9b0493a.jpg',
#  'data/derived/bb_images/beauty_image/2875f2cb3b209c17ac8f1f518f85c631.jpg',
#  'data/derived/bb_images/beauty_image/72389a12ad62457a17c9c6b37897dda9.jpg',
#  'data/derived/bb_images/beauty_image/0f54ff16bd4d5eceeb4b9458c7b32efe.jpg',
#  'data/derived/bb_images/beauty_image/399a8e15483aadef28c23a5a4334df1b.jpg',
#  'data/derived/bb_images/beauty_image/b2e5a5f7a73b4b16b9a68d7fc1ecd899.jpg',
#  'data/derived/bb_images/beauty_image/0a7cf0ce242744264600ef0ed06bf163.jpg',
#  'data/derived/bb_images/beauty_image/b7ac1d080a7de36f1920e9b5f02f1ac6.jpg',
#  'data/derived/bb_images/beauty_image/26d6872148614fff76de38a2a51c261d.jpg',
#  'data/derived/bb_images/beauty_image/30e7d06420b3aa27a140abf8baf2e41e.jpg',
#  'data/derived/bb_images/beauty_image/36e468687d6434b1cbd66846177a79a5.jpg',
#  'data/derived/bb_images/beauty_image/e201dcdf2112b0320de75904b229e7b1.jpg',
#  'data/derived/bb_images/beauty_image/24e215f4b5ec55098e5abb7501179f3f.jpg',
#  'data/derived/bb_images/beauty_image/0b07517cabd8075d42f2182dc8e6bfff.jpg',
#  'data/derived/bb_images/beauty_image/0dc0342b49001975a6fd0eab79926ce6.jpg',
#  'data/derived/bb_images/beauty_image/e6909ec6a23ca9467406965ce5b93b23.jpg',
#  'data/derived/bb_images/beauty_image/fc3999c057a88cb04bde99e7a404f399.jpg',
#  'data/derived/bb_images/beauty_image/e34a78ba1d3a7421a3cb91261f8e20d1.jpg',
#  'data/derived/bb_images/beauty_image/7054f3f3dbe9ba97b822e92de1cbeb9f.jpg',
#  'data/derived/bb_images/beauty_image/103509832fd24d726f4ef787c7a25ef7.jpg',
#  'data/derived/bb_images/beauty_image/73bcce39d09dc399d39c01cb0b831782.jpg',
#  'data/derived/bb_images/beauty_image/ad8e1cb9f7b7330fe102c026841008af.jpg',
#  'data/derived/bb_images/beauty_image/8f09a127e250dbe5c9c24062646c2e05.jpg',
#  'data/derived/bb_images/beauty_image/69c62e77e936df077f9e85651753522c.jpg',
#  'data/derived/bb_images/beauty_image/48172223cce941332f1efaf73176cbcb.jpg',
#  'data/derived/bb_images/beauty_image/9de9e7dde309018d9c610250ddddbd69.jpg',
#  'data/derived/bb_images/beauty_image/e94b00dfa620c98c33647f43d34ebb01.jpg',
#  'data/derived/bb_images/beauty_image/9e9644608a04dd4d06f91a3c04fcccae.jpg',
#  'data/derived/bb_images/beauty_image/9ead5f22e57a1763b051874015c76cdc.jpg',
#  'data/derived/bb_images/beauty_image/f27b30cdbd3d955527bcea1994ba6b73.jpg',
#  'data/derived/bb_images/beauty_image/a3120ec94b8673c517d5866d410cbfe9.jpg',
#  'data/derived/bb_images/beauty_image/a8477016d27a1469c51ca1567e82d31f.jpg',
#  'data/derived/bb_images/beauty_image/9f34b0d1d09963cde3165b9f599633fc.jpg',
#  'data/derived/bb_images/beauty_image/6571227002dec4dff6dfe315a44bb428.jpg',
#  'data/derived/bb_images/beauty_image/fb6c697e6357769c9d897973d82eecab.jpg',
#  'data/derived/bb_images/beauty_image/95eeaca25accd9c7c8511cefa7ecf0c9.jpg',
#  'data/derived/bb_images/beauty_image/bdfd1983a3eb1ece9e0d9c38d00e4d80.jpg',
#  'data/derived/bb_images/beauty_image/2bb9fea595a6450a0e373d27ea13ff74.jpg',
#  'data/derived/bb_images/beauty_image/b9aaab34148eacd54aaa69b6e594fb0f.jpg',
#  'data/derived/bb_images/beauty_image/268345d9b074a43a3ce4bdfa37ed3377.jpg',
#  'data/derived/bb_images/beauty_image/952ed74e5000ffe31ef2b2298501368b.jpg',
#  'data/derived/bb_images/beauty_image/f027d639e489e81e84f3aa020397f518.jpg',
#  'data/derived/bb_images/beauty_image/7567aa32e59e060997192d1d6a229d73.jpg',
#  'data/derived/bb_images/beauty_image/3fe5dac676d98b8742ce16189c561cd5.jpg',
#  'data/derived/bb_images/beauty_image/c0a5cdd2a9980a8694c951b4c17ad0cf.jpg',
#  'data/derived/bb_images/beauty_image/618303586d2b35ea6b4d1fe86327f272.jpg',
#  'data/derived/bb_images/beauty_image/c8da409c93df8e51c96795ee32912a2d.jpg',
#  'data/derived/bb_images/beauty_image/c976bde3a8a98cea585c4197a1467154.jpg',
#  'data/derived/bb_images/beauty_image/7f91a4e6f1eadcc2adbdb7be864810b1.jpg',
#  'data/derived/bb_images/beauty_image/33db58c1767ffb5a50ed3574503123d2.jpg',
#  'data/derived/bb_images/beauty_image/638104aacd28a47d91f4abb3faf124dc.jpg',
#  'data/derived/bb_images/beauty_image/c8135eed4aa51ddadfb55e3460777bb4.jpg',
#  'data/derived/bb_images/beauty_image/c8102a034e4ae6363061d7764351141d.jpg',
#  'data/derived/bb_images/beauty_image/efeb24721aa6cb44429b13d7672f966e.jpg',
#  'data/derived/bb_images/beauty_image/c7ab4e63544f859bc8a5138b36b0fc9f.jpg',
#  'data/derived/bb_images/beauty_image/bc074a8b784613e8ffc9dec98371da4a.jpg',
#  'data/derived/bb_images/beauty_image/f92df921f48d4732d021ce29545e870e.jpg',
#  'data/derived/bb_images/beauty_image/9d31c360a193ebac5ff36a76b9bfca64.jpg',
#  'data/derived/bb_images/beauty_image/71a5723238efd28579b816bd05b2fff2.jpg',
#  'data/derived/bb_images/beauty_image/eff50647528f4b023bc0115b1571286a.jpg',
#  'data/derived/bb_images/beauty_image/486ec06feb83ababa87146f196eadef9.jpg',
#  'data/derived/bb_images/beauty_image/98802b391639cd647e055771131880ca.jpg',
#  'data/derived/bb_images/beauty_image/099efbecc0791c49b9482dcffc8362a9.jpg',
#  'data/derived/bb_images/beauty_image/dfcc8e35103d24d7e46eb26ea64ea366.jpg',
#  'data/derived/bb_images/beauty_image/88a17efe6a6e8d3069930b79d5a23f08.jpg',
#  'data/derived/bb_images/beauty_image/8aa8bd7753e459331d4a2db11fc4ac25.jpg',
#  'data/derived/bb_images/beauty_image/28200dce1c3a072ab184931762aeb83f.jpg',
#  'data/derived/bb_images/beauty_image/d3984313557d63e37faad2b0c53f6524.jpg',
#  'data/derived/bb_images/beauty_image/eeac0c9c841bb58e5df68a1a498f8379.jpg',
#  'data/derived/bb_images/beauty_image/55a956ffa91cee789ab4ac0219c83ed5.jpg',
#  'data/derived/bb_images/beauty_image/980fba7378faf6f8737bf5b5ab1c24a7.jpg',
#  'data/derived/bb_images/beauty_image/d8194fff6638276d04fb3dbb3caa3a5b.jpg',
#  'data/derived/bb_images/beauty_image/0b5da6d8f8501c46bfb1aaa7d455f64d.jpg',
#  'data/derived/bb_images/beauty_image/ba95b3f3565b04e159acf441d92e6248.jpg',
#  'data/derived/bb_images/beauty_image/cb5a8745cd6b566f05293e7c07aa9ee8.jpg',
#  'data/derived/bb_images/beauty_image/2e081170b93a769ca842f83df5225ffd.jpg',
#  'data/derived/bb_images/beauty_image/70932165a041b3af52fab2ae45557f93.jpg',
#  'data/derived/bb_images/beauty_image/3b921510a23cc15f03323b9ad0be6e1a.jpg',
#  'data/derived/bb_images/beauty_image/8971b7f0859cc7360f4a7f49a63237c3.jpg',
#  'data/derived/bb_images/beauty_image/1477eb28feba50046746903d2d5f0349.jpg',
#  'data/derived/bb_images/beauty_image/8de498eee0dbdf8ac1fe5f40e7f53de8.jpg',
#  'data/derived/bb_images/beauty_image/a848488d27841c926cfcaf045732b45f.jpg',
#  'data/derived/bb_images/beauty_image/8b72b80d857fe74d427cead320661eb6.jpg',
#  'data/derived/bb_images/beauty_image/3728388c111ad564550a989d17ce3b72.jpg',
#  'data/derived/bb_images/beauty_image/cc51bf35a3d4fc9f9e882d167bb9f5ba.jpg',
#  'data/derived/bb_images/beauty_image/27db237668c7e5592844b3dc0f344b76.jpg',
#  'data/derived/bb_images/beauty_image/4575a5943b5680ef3d2a4d15593d664e.jpg',
#  'data/derived/bb_images/beauty_image/9de42b5b28d5a4afd0fb0f8f77c95199.jpg',
#  'data/derived/bb_images/beauty_image/2c1c660c1f571262251f4991dfd9fd83.jpg',
#  'data/derived/bb_images/beauty_image/924b1b1ebe5133d8adb2716bae1a0a05.jpg',
#  'data/derived/bb_images/beauty_image/856a23ebc6df8534c913c420553264dd.jpg',
#  'data/derived/bb_images/beauty_image/da33c96e59d8e6ec3d58b16f85c9f6b4.jpg',
#  'data/derived/bb_images/beauty_image/490bc437d4d43fcfbd3bd160071a30ec.jpg',
#  'data/derived/bb_images/beauty_image/41e993c301fd591e21fe1329fef2a720.jpg',
#  'data/derived/bb_images/beauty_image/801dbd71798685e7bc76bcf57d772176.jpg',
#  'data/derived/bb_images/beauty_image/76bbbe82e5340517c27632cbd0b6a579.jpg',
#  'data/derived/bb_images/beauty_image/5c84fc4c88f4aa4761f928cbdd273e7c.jpg',
#  'data/derived/bb_images/beauty_image/6c53d538f5fd32d44a46ac15199f4cf2.jpg',
#  'data/derived/bb_images/beauty_image/06a1784e055cfd78ffc2c96011603ddb.jpg',
#  'data/derived/bb_images/beauty_image/54f811041a5a2b9b446b84629366658f.jpg',
#  'data/derived/bb_images/beauty_image/67790e6109d5c4eadd0eaa3c51ac0291.jpg',
#  'data/derived/bb_images/beauty_image/232af07be4a9989358dd046df3e1ac0d.jpg',
#  'data/derived/bb_images/beauty_image/b0d3267a9d73d2be0d67e5994c6f42ce.jpg',
#  'data/derived/bb_images/beauty_image/fc902c71dc2f2c944157ead0c171a606.jpg',
#  'data/derived/bb_images/beauty_image/6c6eabf3c3dff19ee65bb46b33ef4e4e.jpg',
#  'data/derived/bb_images/beauty_image/0a0d292a88887907fa538ca4c86c0c24.jpg',
#  'data/derived/bb_images/beauty_image/3c8eb6d0f2df425fc9916b9cdfdc7c82.jpg',
#  'data/derived/bb_images/beauty_image/079f4e21229d2c89a21a2f4bdf69ea67.jpg',
#  'data/derived/bb_images/beauty_image/f81d8da68646658258d66b70a1710961.jpg',
#  'data/derived/bb_images/beauty_image/89d51c75e32c2b4770e895c4f9a152f9.jpg',
#  'data/derived/bb_images/beauty_image/6bf58ccceb8585fc7b59ee8833ef9cea.jpg',
#  'data/derived/bb_images/beauty_image/c80682af79649ba9d8346d5e518b8a89.jpg',
#  'data/derived/bb_images/beauty_image/059fc490790a740d9a1138edadbe309b.jpg',
#  'data/derived/bb_images/beauty_image/7177f6d023b2a49c684102c562e273d5.jpg',
#  'data/derived/bb_images/beauty_image/7d9920fb23e2363cf7100948efbf4040.jpg',
#  'data/derived/bb_images/beauty_image/c32a7599f3497a772b7b7359ebf0654b.jpg',
#  'data/derived/bb_images/beauty_image/88623604ef349e8a978d17938c5a556e.jpg',
#  'data/derived/bb_images/beauty_image/011582d10fd1a14db8f057d86ee623f1.jpg',
#  'data/derived/bb_images/beauty_image/8750b72809b3e0797587b15c94592778.jpg',
#  'data/derived/bb_images/beauty_image/493570de4ea53855c3de9ed0e0d06483.jpg',
#  'data/derived/bb_images/beauty_image/4553d6854b20786e53c8a1b2ea58428d.jpg',
#  'data/derived/bb_images/beauty_image/00a8c1b460e850ca131f8bf4fb2489ae.jpg',
#  'data/derived/bb_images/beauty_image/3a75321999db45f9d9818584da759632.jpg',
#  'data/derived/bb_images/beauty_image/f57b304210af3ac82faf03d8de57d006.jpg',
#  'data/derived/bb_images/beauty_image/7b394e4c6b400ea09153b971ecd434b8.jpg',
#  'data/derived/bb_images/beauty_image/ce9492e88c3efa49490a19056106eaf2.jpg',
#  'data/derived/bb_images/beauty_image/1954ed7c42086eb771385f757a54ae7e.jpg',
#  'data/derived/bb_images/beauty_image/2cc2f3871571c4d7d1d0f2de892a0c42.jpg',
#  'data/derived/bb_images/beauty_image/c569dd5c7967280c2cfb310bbe49b3b3.jpg',
#  'data/derived/bb_images/beauty_image/3bc9f8d0b2e17fcb08b390f68cd22a90.jpg',
#  'data/derived/bb_images/beauty_image/4e3b62058ef8df1c81ddd72dc6faa0a5.jpg',
#  'data/derived/bb_images/beauty_image/056abbc5db78dcac96e1d00ae02cd89b.jpg',
#  'data/derived/bb_images/beauty_image/827fa4426f9bd1c8b09a5db1623100d2.jpg',
#  'data/derived/bb_images/beauty_image/c377b4f5c55ce3e61757f0e4fe8832f3.jpg',
#  'data/derived/bb_images/beauty_image/961ea3348e9a3d69a2028d57c6e1f813.jpg',
#  'data/derived/bb_images/beauty_image/6e0089fdf9ff6496c213843b393ec8da.jpg',
#  'data/derived/bb_images/beauty_image/bc8dccb35173d86530f4319490cda36c.jpg',
#  'data/derived/bb_images/beauty_image/cda8872d5c161540bd89cd370f1a6d2a.jpg',
#  'data/derived/bb_images/beauty_image/ed60baf5b8fb985c31929aed56159975.jpg',
#  'data/derived/bb_images/beauty_image/97ccbfe653b984c31ac162850f192208.jpg',
#  'data/derived/bb_images/beauty_image/2afbfcb1570668712926dde0aa534387.jpg',
#  'data/derived/bb_images/beauty_image/9790a6e7d44b4abdd18e658dc1b2a635.jpg',
#  'data/derived/bb_images/beauty_image/4f2c955e8b04a6bbfdf0aa4a73ba26e1.jpg',
#  'data/derived/bb_images/beauty_image/7792b70dab564da5a0af5f523fb89e17.jpg',
#  'data/derived/bb_images/beauty_image/47cb3a44b12d3f38a1d777af115fa0a8.jpg',
#  'data/derived/bb_images/beauty_image/bac0dab2f6f802db1091901e00df4bad.jpg',
#  'data/derived/bb_images/beauty_image/c2f34dc37956d35e80c2f99b7acca891.jpg',
#  'data/derived/bb_images/beauty_image/48ce35874738c66282cc47747f0f63c9.jpg',
#  'data/derived/bb_images/beauty_image/f34c69400f091e52a186027149bee3e8.jpg',
#  'data/derived/bb_images/beauty_image/128e9f8b7709ee3baec114f61c7db196.jpg',
#  'data/derived/bb_images/beauty_image/ba678e179aa0e59a8c3d934a3746cba7.jpg',
#  'data/derived/bb_images/beauty_image/8746c7796be4997d9dc43bf2bf77da47.jpg',
#  'data/derived/bb_images/beauty_image/86a5ebd4f34829106a4d7dfd88ed0d7f.jpg',
#  'data/derived/bb_images/beauty_image/d20b04b5e3b00531e1a90960a2948827.jpg',
#  'data/derived/bb_images/beauty_image/1cd8e250e98a9ac5f0c6d39b935a8868.jpg',
#  'data/derived/bb_images/beauty_image/18fc76c94688aa2f8e7bcac8a094ad09.jpg',
#  'data/derived/bb_images/beauty_image/306c20f49f7426da0265058966d417d9.jpg',
#  'data/derived/bb_images/beauty_image/b400bf5cfc3cfa51c56be790f2e88337.jpg',
#  'data/derived/bb_images/beauty_image/4fbc2f75806847a2a1cc126ec0a6b35a.jpg',
#  'data/derived/bb_images/beauty_image/fb4769797890f1060457e8acb7635d7c.jpg',
#  'data/derived/bb_images/beauty_image/4aa23b5e98b1b91b1c1892819cf84705.jpg',
#  'data/derived/bb_images/beauty_image/d0bb75faf2b96891b1f157e2cf9c7d35.jpg',
#  'data/derived/bb_images/beauty_image/498010263cdd4f94fbff48e92fdaffe7.jpg',
#  'data/derived/bb_images/beauty_image/d33f663e3e5984c4346f369a7d9d0bb5.jpg',
#  'data/derived/bb_images/beauty_image/823644623d0c7594e8522bad347c5cf7.jpg',
#  'data/derived/bb_images/beauty_image/8f0aab35ec8d09e4bf81a44ee07208f6.jpg',
#  'data/derived/bb_images/beauty_image/fdf1d019a3e2a86a8070610b2cd9429f.jpg',
#  'data/derived/bb_images/beauty_image/be612037365dde48960d64448ee88182.jpg',
#  'data/derived/bb_images/beauty_image/ee5f51394213bc240586c04e19aa9a7e.jpg',
#  'data/derived/bb_images/beauty_image/35cb17512b865a7dffd7dde4d89c6938.jpg',
#  'data/derived/bb_images/beauty_image/0edcb0afe67d32b8b8b9ba868ff101ed.jpg',
#  'data/derived/bb_images/beauty_image/1640585a7c5b350deaef489d73e3d318.jpg',
#  'data/derived/bb_images/beauty_image/760a3c789923164ddbbfc40f98a7dca9.jpg',
#  'data/derived/bb_images/beauty_image/d465ac9895feaab44b3f4e0c175bec6a.jpg',
#  'data/derived/bb_images/beauty_image/54b28b5d63ff36ea67643c1e0297f394.jpg',
#  'data/derived/bb_images/beauty_image/dc07749f51e724d95c88492cde56fdbf.jpg',
#  'data/derived/bb_images/beauty_image/aeeff8ddba9400989a61a85c1d4854a0.jpg',
#  'data/derived/bb_images/beauty_image/5879a2eb87ffb45d625ec00a03c52fce.jpg',
#  'data/derived/bb_images/beauty_image/a2e2471cb69f829f0b2420d873eb09ba.jpg',
#  'data/derived/bb_images/beauty_image/ab9567b3932b185a4bf2e1a4583ab840.jpg',
#  'data/derived/bb_images/beauty_image/f134c9e617971eed4aa8b3cb697f4c6d.jpg',
#  'data/derived/bb_images/beauty_image/c0d873e96463beded5d49f24e24c7a70.jpg',
#  'data/derived/bb_images/beauty_image/5b38ec8c06d0623fce749eb475e6f239.jpg',
#  'data/derived/bb_images/beauty_image/7e581d4421490a7aa99e201d458533a3.jpg',
#  'data/derived/bb_images/beauty_image/e8f9cb9c04387762471d00e99eff4198.jpg',
#  'data/derived/bb_images/beauty_image/11bc1f2c9d1ddab28f54fe0dfc140b66.jpg',
#  'data/derived/bb_images/beauty_image/a47d61b34986ced5cf3a2b239701dfeb.jpg',
#  'data/derived/bb_images/beauty_image/2e94f2af377314ca235695d9cdffe011.jpg',
#  'data/derived/bb_images/beauty_image/386241af76a31966ea74714677a089de.jpg',
#  'data/derived/bb_images/beauty_image/fee2ddc9136a3a7f8f022283e7f85ff6.jpg',
#  'data/derived/bb_images/beauty_image/568b5eb3c8720d368ab0f279881808e0.jpg',
#  'data/derived/bb_images/beauty_image/01b38a5c2d46b1e023e9f94cfb0099fc.jpg',
#  'data/derived/bb_images/beauty_image/f432975e4c7301f3d5ca5eb9d8254bd6.jpg',
#  'data/derived/bb_images/beauty_image/d997a727e24605e5c5b6f95ea2d885f3.jpg',
#  'data/derived/bb_images/beauty_image/9bc697f7a03c69218e7fc568f5e417b5.jpg',
#  'data/derived/bb_images/beauty_image/1b66adff9ce02dfcd7c749f00c2b3c73.jpg',
#  'data/derived/bb_images/beauty_image/9ef6c609949d6648f192c2ed610d7825.jpg',
#  'data/derived/bb_images/beauty_image/002bced4d1dc109f5e1fafdf16d3a0d9.jpg',
#  'data/derived/bb_images/beauty_image/430bdd04fef64904a6c9d5ad986aad9f.jpg',
#  'data/derived/bb_images/beauty_image/6a6ae6bcdbfc5a190c17ade7dfd195c5.jpg',
#  'data/derived/bb_images/beauty_image/49bccdb54fe0c89ce4f0b2fa68513860.jpg',
#  'data/derived/bb_images/beauty_image/400acd2ade6918c2ce0e442ac28b1744.jpg',
#  'data/derived/bb_images/beauty_image/cc6461f5dea9a5a67b0e81ad79223b1d.jpg',
#  'data/derived/bb_images/beauty_image/69223e8a046d6fac55f894b5e35b21f8.jpg',
#  'data/derived/bb_images/beauty_image/2b2521d0f793f5fbc1205cf7cf3aa3c3.jpg',
#  'data/derived/bb_images/beauty_image/307867e9e97ed30ec161931403846e35.jpg',
#  'data/derived/bb_images/beauty_image/377da2390c2b04e70a199869999d9a6d.jpg',
#  'data/derived/bb_images/beauty_image/8b6b758d3db865dc409a3eebf8398275.jpg',
#  'data/derived/bb_images/beauty_image/b02c567013a67b039c35319f69a95f9a.jpg',
#  'data/derived/bb_images/beauty_image/0bdf03ca6054857b0ca720e3cd9894ab.jpg',
#  'data/derived/bb_images/beauty_image/079a4b0ac88c0b0cb6372b9e64decdb1.jpg',
#  'data/derived/bb_images/beauty_image/c6c4947ab5aa5c714879a3cc3ef3ac39.jpg',
#  'data/derived/bb_images/beauty_image/df2edb4fd626fe5f54c90dec2f44e29e.jpg',
#  'data/derived/bb_images/beauty_image/d62cd79f1a641ee2475b1da07fed983a.jpg',
#  'data/derived/bb_images/beauty_image/92b9c1834cc69c016e7a6dea7a7c4ce4.jpg',
#  'data/derived/bb_images/beauty_image/673261b1a2f83ef83cdb457a655295e0.jpg',
#  'data/derived/bb_images/beauty_image/0e90f4cdd4913be0313f0b6c91bd6e48.jpg',
#  'data/derived/bb_images/beauty_image/d111097759a5cd87ce2f1a963ea44108.jpg',
#  'data/derived/bb_images/beauty_image/be592db413493df1bac5c10a8db7d2d6.jpg',
#  'data/derived/bb_images/beauty_image/745e2f78b1e1b3418cc0225271c69f74.jpg',
#  'data/derived/bb_images/beauty_image/f851e5d9a3ba42ab6c4096cfd1a4aae4.jpg',
#  'data/derived/bb_images/beauty_image/eaa532b4bce3913a4345065860313fa9.jpg',
#  'data/derived/bb_images/beauty_image/303e4fc91910fdd4f6b76197b1a3b3c7.jpg',
#  'data/derived/bb_images/beauty_image/ddc67433d888904fb209de6f21173054.jpg',
#  'data/derived/bb_images/beauty_image/d569baee8dbac5f86aaf19b3ae68726b.jpg',
#  'data/derived/bb_images/beauty_image/78bea8476c50e3d710ea8ec2e6b4a11a.jpg',
#  'data/derived/bb_images/beauty_image/3cf277ce64cef1352ba08c0d947fcd75.jpg',
#  'data/derived/bb_images/beauty_image/dce2fd638b544f91c0ef8722a05717ad.jpg',
#  'data/derived/bb_images/beauty_image/000bd276004d9c929d40cb6f95b854dc.jpg',
#  'data/derived/bb_images/beauty_image/c116ea0fa2c6ead36c17616e7887d060.jpg',
#  'data/derived/bb_images/beauty_image/79d50602f1e1034254494d4e2300d4aa.jpg',
#  'data/derived/bb_images/beauty_image/db5d2e331c84df06aa527582a83eea07.jpg',
#  'data/derived/bb_images/beauty_image/72398e6f760da441351c58a08942dba6.jpg',
#  'data/derived/bb_images/beauty_image/8b7a8b2e3eee0164ad24359b47b5592e.jpg',
#  'data/derived/bb_images/beauty_image/5f8df12ad10133d7f77bda1d65f6d8de.jpg',
#  'data/derived/bb_images/beauty_image/c15f029bdff89b1ed8544daa56878504.jpg']

# %%
with zipfile.ZipFile('bb_images.zip', 'w') as zipped_folder:
    for file in glob.glob('data/derived/bb_images/beauty_image/*.jpg'):
        zipped_folder.write(file)
    for file in glob.glob('data/derived/bb_images/fashion_image/*.jpg'):
        zipped_folder.write(file)
    for file in glob.glob('data/derived/bb_images/mobile_image/*.jpg'):
        zipped_folder.write(file)

# %% [markdown]
# Image paths of samples

# %%
df_beauty_sample[['image_path']].to_csv('data/derived/beauty_image_path_bb.csv', index=False)
df_fashion_sample[['image_path']].to_csv('data/derived/fashion_image_path_bb.csv', index=False)
df_mobile_sample[['image_path']].to_csv('data/derived/mobile_image_path_bb.csv', index=False)
